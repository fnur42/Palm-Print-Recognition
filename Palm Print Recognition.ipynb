# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
from skimage import morphology
import numpy as np
import glob
import os
import cv2
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.cluster import KMeans
from tensorflow.keras.callbacks import EarlyStopping

class Palm_Graph():
    def __init__(self, train, test):
        assert (np.array(train).shape == np.array(test).shape)
        self.train = train
        self.test = test
        self.rows, self.cols = train[0].shape

def Low_pass_Gaussian_process(img, D0):
    rows, cols = img.shape
    mask = np.zeros((rows, cols))
    Locx = np.array(list(range(cols)) * rows).reshape([rows, cols])
    Locy = np.transpose((np.array(list(range(rows)) * cols).reshape([cols, rows])))
    D = np.sqrt((Locx - cols / 2) ** 2 + (Locy - rows / 2) ** 2)
    mask = np.exp(-D ** 2 / D0 ** 2 / 2)

    f1 = np.fft.fft2(img)
    f1shift = np.fft.fftshift(f1)
    f1shift = f1shift * mask
    f2shift = np.fft.ifftshift(f1shift)
    img_new = np.fft.ifft2(f2shift)
    img_new = np.abs(img_new)

    return img_new

class gabor():
    def __init__(self, R, C, n_orientation, scale):
        self.R = R
        self.C = C
        self.n_orientarion = n_orientation
        self.scale = scale
        self.orientation = np.array([u * np.pi / n_orientation for u in range(1, n_orientation + 1)])
        self.gabor_filters_sets = [gabor_wavelet(R, C, u, scale, n_orientation) for u in range(1, n_orientation + 1)]

    def filtering(self, img):
        graphs = np.array([cv2.filter2D(img, -1, np.real(gw)) for gw in self.gabor_filters_sets])
        return graphs

    def plot_filters(self, n_scale):
        gabor_filters = []
        fig = plt.figure()
        for v in range(1, n_scale + 1):
            for u in range(1, self.n_orientarion + 1):
                gw = gabor_wavelet(self.R, self.C, u, v, self.n_orientarion)
                fig.add_subplot(n_scale, self.n_orientarion, self.n_orientarion * (v - 1) + u)
                plt.imshow(np.real(gw), cmap='gray')
        plt.show()

def gabor_wavelet(rows, cols, orientation, scale, n_orientation):
    kmax = np.pi / 2
    f = np.sqrt(2)
    delt2 = (2 * np.pi) ** 2
    k = (kmax / (f ** scale)) * np.exp(1j * orientation * np.pi / n_orientation / 2)
    kn2 = np.abs(k) ** 2
    gw = np.zeros((rows, cols), np.float32)

    for m in range(int(-rows / 2) + 1, int(rows / 2) + 1):
        for n in range(int(-cols / 2) + 1, int(cols / 2) + 1):
            t1 = np.exp(-0.5 * kn2 * (m ** 2 + n ** 2) / delt2)
            t2 = np.exp(1j * (np.real(k) * m + np.imag(k) * n))
            t3 = np.exp(-0.5 * delt2)
            gw[int(m + rows / 2 - 1), int(n + cols / 2 - 1)] = (kn2 / delt2) * t1 * (t2 - t3).real

    return gw

def get_data(number):
    number = str(number)
    train_files = sorted(glob.glob(os.path.join(train_data_path, number.zfill(3) + '*.bmp')))
    test_files = sorted(glob.glob(os.path.join(test_data_path, number.zfill(3) + '*.bmp')))
    train_data = [imread(graph) for graph in train_files]
    test_data = [imread(graph) for graph in test_files]
    palm = Palm_Graph(train_data, test_data)
    return palm

def LOG_preprocess(img, R0=40, ksize=5):
    AfterGaussian = np.uint8(Low_pass_Gaussian_process(img, R0))
    processed = cv2.Laplacian(AfterGaussian, -1, ksize=ksize)
    img = cv2.equalizeHist(img)
    return processed

def process(img):
    img = LOG_preprocess(img)

    After_gabor = []
    for i, gw in enumerate(gabor_filters):
        element = cv2.filter2D(img, -1, np.real(gw))
        After_gabor.append(element)

    Two_value = []
    for i, line in enumerate(After_gabor):
        _, TW = cv2.threshold(line, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)

        kernel = np.ones((2, 2), np.uint8)
        TW = cv2.erode(TW, kernel)

        Two_value.append(TW)
    con = []
    for i in Two_value:
        conective = morphology.remove_small_objects(i > 0, min_size=40, connectivity=1)
        con.append(conective)

    line = (np.sum(con, axis=0) / len(con))

    return line

train_data_path = '/kaggle/input/palmprint/Palmprint/training'
test_data_path = '/kaggle/input/palmprint/Palmprint/testing'
n_orientation = 8
scale = 4
GA = gabor(10, 10, n_orientation, scale)
gabor_filters = GA.gabor_filters_sets
GA.plot_filters(3)

def extract_features(data):
    features = []
    for img in data:
        processed_img = process(img)
        features.append(processed_img)
    return np.array(features)

train_data = []
train_labels = []
test_data = []
test_labels = []

for i in range(1, 100):
    palm = get_data(i)
    train_features = extract_features(palm.train)
    test_features = extract_features(palm.test)
    train_data.extend(train_features)
    test_data.extend(test_features)
    train_labels.extend([i] * len(train_features))
    test_labels.extend([i] * len(test_features))

train_data = np.array(train_data)
test_data = np.array(test_data)
train_labels = np.array(train_labels)
test_labels = np.array(test_labels)

# Veriyi CNN için uygun şekle getirme
train_data = train_data[..., np.newaxis]
test_data = test_data[..., np.newaxis]

# Etiketleri one-hot encoding ile dönüştürme
train_labels = to_categorical(train_labels, num_classes=100)
test_labels = to_categorical(test_labels, num_classes=100)

# Veriyi artırma
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True)

datagen.fit(train_data)

# CNN Modeli
model = Sequential([
    Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(train_data.shape[1], train_data.shape[2], 1)),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),
    Conv2D(64, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),
    Conv2D(128, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(100, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Erken durdurma tanımlama
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Modeli eğitme
history = model.fit(datagen.flow(train_data, train_labels, batch_size=32), 
          validation_data=(test_data, test_labels), 
          epochs=100, 
          callbacks=[early_stopping])

# Eğitim ve doğrulama doğruluk ve kayıp değerlerini çizdirme
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Eğitim Doğruluğu')
plt.plot(history.history['val_accuracy'], label='Doğrulama Doğruluğu')
plt.title('Doğruluk')
plt.xlabel('Epok')
plt.ylabel('Doğruluk')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Eğitim Kaybı')
plt.plot(history.history['val_loss'], label='Doğrulama Kaybı')
plt.title('Kayıp')
plt.xlabel('Epok')
plt.ylabel('Kayıp')
plt.legend()

plt.show()

# Test verisi ile doğrulama
test_loss, test_accuracy = model.evaluate(test_data, test_labels)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

palm2 = get_data(2)

train_image = palm2.train[0]
test_image = palm2.test[0]

train_processed = process(train_image)
test_processed = process(test_image)

orb = cv2.ORB_create()
kp1, des1 = orb.detectAndCompute(np.uint8(train_processed * 255), None)
kp2, des2 = orb.detectAndCompute(np.uint8(test_processed * 255), None)

bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
matches = bf.match(des1, des2)

# Eğitim ve test görüntülerinde özellik noktalarını ve eşleşmeleri görselleştirme
train_image_color = cv2.cvtColor(train_image, cv2.COLOR_GRAY2BGR)
test_image_color = cv2.cvtColor(test_image, cv2.COLOR_GRAY2BGR)

# Eğitim görüntüsündeki özellik noktaları kırmızı (BGR: (0, 0, 255))
for kp in kp1:
    x, y = kp.pt
    cv2.circle(train_image_color, (int(x), int(y)), 5, (0, 0, 255), -1)

# Test görüntüsündeki özellik noktaları mavi (BGR: (255, 0, 0))
for kp in kp2:
    x, y = kp.pt
    cv2.circle(test_image_color, (int(x), int(y)), 5, (255, 0, 0), -1)

# Eşleşen noktaları yeşil çizgilerle görselleştirme (BGR: (0, 255, 0))
matches_img = cv2.drawMatches(train_image_color, kp1, test_image_color, kp2, matches, None, matchColor=(0, 255, 0), flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

fig, axes = plt.subplots(1, 2, figsize=(15, 5))
axes[0].imshow(cv2.cvtColor(train_image_color, cv2.COLOR_BGR2RGB))
axes[0].set_title('Eğitim Görüntüsü')
axes[1].imshow(cv2.cvtColor(test_image_color, cv2.COLOR_BGR2RGB))
axes[1].set_title('Test Görüntüsü')

plt.figure(figsize=(15, 5))
plt.imshow(cv2.cvtColor(matches_img, cv2.COLOR_BGR2RGB))
plt.title('Özellik Noktaları ve Eşleşmeler')
plt.show()

# Otsu Thresholding
_, otsu_thresh_train = cv2.threshold(train_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
_, otsu_thresh_test = cv2.threshold(test_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# K-means Segmentation
def kmeans_segmentation(img, k=2):
    img_flat = img.reshape((-1, 1))
    kmeans = KMeans(n_clusters=k, random_state=0).fit(img_flat)
    segmented_img = kmeans.labels_.reshape(img.shape)
    return segmented_img

kmeans_train = kmeans_segmentation(train_image, k=2)
kmeans_test = kmeans_segmentation(test_image, k=2)

# Otsu ve K-means sonuçlarını görselleştirme
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes[0, 0].imshow(otsu_thresh_train, cmap='gray')
axes[0, 0].set_title('Eğitim Görüntüsü - Otsu Thresholding')
axes[0, 1].imshow(otsu_thresh_test, cmap='gray')
axes[0, 1].set_title('Test Görüntüsü - Otsu Thresholding')

axes[1, 0].imshow(kmeans_train, cmap='gray')
axes[1, 0].set_title('Eğitim Görüntüsü - K-means Segmentation')
axes[1, 1].imshow(kmeans_test, cmap='gray')
axes[1, 1].set_title('Test Görüntüsü - K-means Segmentation')

plt.show()
# Out:
# 2024-06-07 12:04:09.850892: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-07 12:04:09.850994: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-07 12:04:09.964580: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2024-06-07 12:04:38.124481: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.39151, expected 2.7295
# 2024-06-07 12:04:38.124539: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 3.36773, expected 2.70572
# 2024-06-07 12:04:38.124548: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 3.08268, expected 2.42067
# 2024-06-07 12:04:38.124556: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 3.1679, expected 2.50589
# 2024-06-07 12:04:38.124564: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 2.96544, expected 2.30343
# 2024-06-07 12:04:38.124572: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 2.78427, expected 2.12226
# 2024-06-07 12:04:38.124580: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 2.73395, expected 2.07194
# 2024-06-07 12:04:38.124587: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 2.30386, expected 1.64185
# 2024-06-07 12:04:38.124595: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 1.89871, expected 1.2367
# 2024-06-07 12:04:38.124603: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 2.62584, expected 1.96383
# 2024-06-07 12:04:38.131987: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,32,126,126]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,128,128]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-06-07 12:04:38.132019: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-06-07 12:04:38.132028: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-06-07 12:04:38.132038: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-06-07 12:04:38.132045: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-06-07 12:04:38.132060: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-06-07 12:04:38.412358: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.39151, expected 2.7295
# 2024-06-07 12:04:38.412414: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 3.36773, expected 2.70572
# 2024-06-07 12:04:38.412423: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 3.08268, expected 2.42067
# 2024-06-07 12:04:38.412431: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 3.1679, expected 2.50589
# 2024-06-07 12:04:38.412438: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 2.96544, expected 2.30343
# 2024-06-07 12:04:38.412446: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 2.78427, expected 2.12226
# 2024-06-07 12:04:38.412454: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 2.73395, expected 2.07194
# 2024-06-07 12:04:38.412461: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 2.30386, expected 1.64185
# 2024-06-07 12:04:38.412469: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 1.89871, expected 1.2367
# 2024-06-07 12:04:38.412477: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 2.62584, expected 1.96383
# 2024-06-07 12:04:38.419491: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,32,126,126]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,128,128]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-06-07 12:04:38.419533: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-06-07 12:04:38.419542: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-06-07 12:04:38.419550: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-06-07 12:04:38.419557: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-06-07 12:04:38.419574: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
#  1/10 ━━━━━━━━━━━━━━━━━━━━ 1:39 11s/step - accuracy: 0.0000e+00 - loss: 4.6321
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717761883.464546      67 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-06-07 12:04:45.899442: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 66: 1.00346, expected 0.767333
# 2024-06-07 12:04:45.899503: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 324: 1.21269, expected 0.976564
# 2024-06-07 12:04:45.899513: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 424: 1.29739, expected 1.06126
# 2024-06-07 12:04:45.899521: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 464: 1.18675, expected 0.950618
# 2024-06-07 12:04:45.899530: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 658: 1.09255, expected 0.85642
# 2024-06-07 12:04:45.899538: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 676: 1.32535, expected 1.08922
# 2024-06-07 12:04:45.899546: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 832: 1.33263, expected 1.0965
# 2024-06-07 12:04:45.899554: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 833: 1.26772, expected 1.03159
# 2024-06-07 12:04:45.899562: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 933: 1.30144, expected 1.06531
# 2024-06-07 12:04:45.899570: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1071: 1.1675, expected 0.931367
# 2024-06-07 12:04:45.899585: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[9,32,126,126]{3,2,1,0}, u8[0]{0}) custom-call(f32[9,1,128,128]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-06-07 12:04:45.899593: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-06-07 12:04:45.899600: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-06-07 12:04:45.899607: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-06-07 12:04:45.899614: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-06-07 12:04:45.899626: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-06-07 12:04:45.944654: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 66: 1.00346, expected 0.767333
# 2024-06-07 12:04:45.944710: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 324: 1.21269, expected 0.976564
# 2024-06-07 12:04:45.944720: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 424: 1.29739, expected 1.06126
# 2024-06-07 12:04:45.944728: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 464: 1.18675, expected 0.950618
# 2024-06-07 12:04:45.944736: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 658: 1.09255, expected 0.85642
# 2024-06-07 12:04:45.944744: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 676: 1.32535, expected 1.08922
# 2024-06-07 12:04:45.944752: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 832: 1.33263, expected 1.0965
# 2024-06-07 12:04:45.944760: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 833: 1.26772, expected 1.03159
# 2024-06-07 12:04:45.944768: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 933: 1.30144, expected 1.06531
# 2024-06-07 12:04:45.944777: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1071: 1.1675, expected 0.931367
# 2024-06-07 12:04:45.944793: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[9,32,126,126]{3,2,1,0}, u8[0]{0}) custom-call(f32[9,1,128,128]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-06-07 12:04:45.944802: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-06-07 12:04:45.944809: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-06-07 12:04:45.944816: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-06-07 12:04:45.944823: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-06-07 12:04:45.944835: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 938ms/step - accuracy: 0.0027 - loss: 4.8074 - val_accuracy: 0.0168 - val_loss: 4.5833
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0053 - loss: 4.9113 - val_accuracy: 0.0101 - val_loss: 4.6061
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.0023 - loss: 5.3950 - val_accuracy: 0.0034 - val_loss: 4.5762
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.0205 - loss: 4.6135 - val_accuracy: 0.0202 - val_loss: 4.5624
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.0129 - loss: 4.6272 - val_accuracy: 0.0168 - val_loss: 4.4856
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.0033 - loss: 4.6187 - val_accuracy: 0.0303 - val_loss: 4.4765
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.0273 - loss: 4.5782 - val_accuracy: 0.0404 - val_loss: 4.4827
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0300 - loss: 4.5267 - val_accuracy: 0.0505 - val_loss: 4.4905
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.0354 - loss: 4.6097 - val_accuracy: 0.0269 - val_loss: 4.4892
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.0232 - loss: 4.5156 - val_accuracy: 0.0168 - val_loss: 4.4714
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.0245 - loss: 4.5328 - val_accuracy: 0.0202 - val_loss: 4.4660
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.0386 - loss: 4.5371 - val_accuracy: 0.0370 - val_loss: 4.4711
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.0230 - loss: 4.5656 - val_accuracy: 0.0505 - val_loss: 4.4276
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.0170 - loss: 4.5155 - val_accuracy: 0.0606 - val_loss: 4.3779
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.0237 - loss: 4.4955 - val_accuracy: 0.0673 - val_loss: 4.3237
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0267 - loss: 4.4612 - val_accuracy: 0.0673 - val_loss: 4.3507
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.0245 - loss: 4.4484 - val_accuracy: 0.1010 - val_loss: 4.3369
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.0508 - loss: 4.4499 - val_accuracy: 0.1077 - val_loss: 4.1467
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.0627 - loss: 4.3503 - val_accuracy: 0.1111 - val_loss: 4.0631
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.0369 - loss: 4.4453 - val_accuracy: 0.1145 - val_loss: 4.1196
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0437 - loss: 4.3109 - val_accuracy: 0.1246 - val_loss: 4.0842
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.0250 - loss: 4.3324 - val_accuracy: 0.1481 - val_loss: 4.0095
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.0687 - loss: 4.1620 - val_accuracy: 0.1616 - val_loss: 3.9307
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.0823 - loss: 4.2722 - val_accuracy: 0.1481 - val_loss: 3.9316
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.0730 - loss: 4.1521 - val_accuracy: 0.1414 - val_loss: 3.8542
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.0580 - loss: 4.3415 - val_accuracy: 0.1616 - val_loss: 3.8357
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.0452 - loss: 4.1984 - val_accuracy: 0.1549 - val_loss: 3.9535
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.0321 - loss: 4.2205 - val_accuracy: 0.1818 - val_loss: 3.7986
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.0450 - loss: 4.1283 - val_accuracy: 0.1380 - val_loss: 4.0133
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0954 - loss: 4.1451 - val_accuracy: 0.1380 - val_loss: 3.9327
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.0752 - loss: 4.1098 - val_accuracy: 0.1818 - val_loss: 3.8293
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.1124 - loss: 4.0548 - val_accuracy: 0.1818 - val_loss: 3.7245
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.0502 - loss: 4.2625 - val_accuracy: 0.1886 - val_loss: 3.9017
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.0909 - loss: 4.0272 - val_accuracy: 0.1987 - val_loss: 3.7548
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.0752 - loss: 4.1311 - val_accuracy: 0.2189 - val_loss: 3.6936
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.0725 - loss: 3.9160 - val_accuracy: 0.1919 - val_loss: 3.6766
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.1031 - loss: 3.7856 - val_accuracy: 0.2189 - val_loss: 3.5052
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.0865 - loss: 3.8888 - val_accuracy: 0.2222 - val_loss: 3.5731
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.1317 - loss: 3.8394 - val_accuracy: 0.2559 - val_loss: 3.4153
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.1141 - loss: 3.8164 - val_accuracy: 0.2559 - val_loss: 3.5287
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.1290 - loss: 3.6306 - val_accuracy: 0.2862 - val_loss: 3.3096
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.1466 - loss: 3.7056 - val_accuracy: 0.2862 - val_loss: 3.2930
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.1184 - loss: 3.7644 - val_accuracy: 0.2828 - val_loss: 3.3465
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.1012 - loss: 3.7744 - val_accuracy: 0.3030 - val_loss: 3.2780
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.1385 - loss: 3.5965 - val_accuracy: 0.3367 - val_loss: 3.1679
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.1089 - loss: 3.7952 - val_accuracy: 0.2997 - val_loss: 3.2712
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.1229 - loss: 3.7731 - val_accuracy: 0.3266 - val_loss: 3.3345
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.1338 - loss: 3.5972 - val_accuracy: 0.3300 - val_loss: 3.2514
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.1316 - loss: 3.6320 - val_accuracy: 0.3098 - val_loss: 3.2719
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.1360 - loss: 3.6589 - val_accuracy: 0.2896 - val_loss: 3.1329
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.1420 - loss: 3.3741 - val_accuracy: 0.3064 - val_loss: 3.2231
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.1062 - loss: 3.7059 - val_accuracy: 0.2828 - val_loss: 3.2157
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.1866 - loss: 3.4698 - val_accuracy: 0.2929 - val_loss: 3.3111
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.1531 - loss: 3.5486 - val_accuracy: 0.3165 - val_loss: 3.0810
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.1287 - loss: 3.5398 - val_accuracy: 0.3805 - val_loss: 3.1176
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.1518 - loss: 3.5833 - val_accuracy: 0.2795 - val_loss: 3.2168
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.1484 - loss: 3.5310 - val_accuracy: 0.3468 - val_loss: 3.0982
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.1475 - loss: 3.6146 - val_accuracy: 0.3838 - val_loss: 3.1909
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.1175 - loss: 3.5258 - val_accuracy: 0.3131 - val_loss: 3.1838
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.1888 - loss: 3.3653 - val_accuracy: 0.3502 - val_loss: 3.0004
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.1804 - loss: 3.2502 - val_accuracy: 0.2862 - val_loss: 3.2073
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.1146 - loss: 3.6085 - val_accuracy: 0.3771 - val_loss: 3.1316
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.1490 - loss: 3.4518 - val_accuracy: 0.3838 - val_loss: 3.0602
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.1966 - loss: 3.1904 - val_accuracy: 0.3266 - val_loss: 3.2389
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.1412 - loss: 3.4673 - val_accuracy: 0.3468 - val_loss: 3.1138
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.1668 - loss: 3.3068 - val_accuracy: 0.3838 - val_loss: 3.0960
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.1728 - loss: 3.4515 - val_accuracy: 0.3030 - val_loss: 3.0981
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.1697 - loss: 3.4238 - val_accuracy: 0.3670 - val_loss: 3.1723
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.1925 - loss: 3.3398 - val_accuracy: 0.3704 - val_loss: 3.0777
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.1924 - loss: 3.3021 - val_accuracy: 0.2795 - val_loss: 3.1775
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3594 - loss: 2.6817
# Test Accuracy: 35.02%
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
